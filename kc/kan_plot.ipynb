# %%
from KC3 import KC3_shipdata as kc3

# %%
kc3.getsqldata()
# Out:
#        no                  name    type        class  fire  fire_max  torpedo  \
# 0     001                    長門      戦艦          長門型    82        99        0
# 1    001b                   長門改      戦艦          長門型    90        99        0
# 2     002                    陸奥      戦艦          長門型    82        99        0
# 3    002b                   陸奥改      戦艦          長門型    90        99        0
# 4     003                    伊勢      戦艦          伊勢型    74        89        0
# 5     004                    日向      戦艦          伊勢型    74        94        0
# 6     005                    雪風     駆逐艦          陽炎型    10        29       24
# 7    005b                   雪風改     駆逐艦          陽炎型    12        59       28
# 8     006                    赤城    正規空母          赤城型     0        39        0
# 9    006b                   赤城改    正規空母          赤城型     0        54        0
# 10    007                    加賀    正規空母          加賀型     0        39        0
# ...

# %%
kc3.getdata()
# Out:
# 0,20,40,60,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\anacondax64\envs\py36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d54164d183b0> in <module>()
# ----> 1 kc3.getdata()
#
# C:\py_notebook\poi\KC3\KC3_shipdata.py in getdata()
#     235
#     236 #    shipdict =  getshipdict()
# --> 237     df = getwikiclass()
# ...
